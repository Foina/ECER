# %%
import pandas as pd
import pykeen
import numpy as np
from pykeen.triples import TriplesFactory
from pykeen.pipeline import pipeline
from sklearn.metrics.pairwise import cosine_similarity
import concurrent.futures
from math import log
import re
import gensim
import nltk
import string
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
import transformers
from transformers import BertTokenizer, BertModel
from sentence_transformers import SentenceTransformer
import torch
from torch import nn
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import torch.nn.functional as F
from torch.utils.data import DataLoader
import requests
import time
import requests, tempfile
from io import BytesIO
from transformers import pipeline
import ast
# Out:
# INFO:pykeen.utils:Using opt_einsum
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
df = pd.read_csv('./dbpedia_irish_places_triples_v2.tsv', sep="\t", names=['head','relation','tail'])

# %%
df.head()
# Out:
#                                                 head         relation  \
# 0       http://dbpedia.org/resource/Holywell,_Swords       rdfs:label
# 1       http://dbpedia.org/resource/Holywell,_Swords     dbo:abstract
# 2       http://dbpedia.org/resource/Holywell,_Swords      dbo:country
# 3       http://dbpedia.org/resource/Holywell,_Swords  dcterms:subject
# 4  http://dbpedia.org/resource/Category:Neighbour...     skos:broader
#
#                                                 tail
# 0                                   Holywell, Swords
# 1  Holywell (Irish: Tobar Naofa) is a neighbourho...
# 2    http://dbpedia.org/resource/Republic_of_Ireland
# 3  http://dbpedia.org/resource/Category:Neighbour...
# 4  http://dbpedia.org/resource/Category:Swords,_D...

# %%
populated_places = pd.read_csv('Irish_populated_places.csv')['place'].unique()

# %%
def generate_embeddings(triples_file, target_entities, model_name='RotatE'):

    df = pd.read_csv(triples_file, sep="\t", names=['head','relation','tail'])


    direct_triples = df[df['head'].isin(target_entities) | df['tail'].isin(target_entities)]
    subjects = set(direct_triples['tail'][direct_triples['relation'] == 'dcterms:subject'])
    broader_subjects = set(df['tail'][df['head'].isin(subjects) & (df['relation'] == 'skos:broader')])

    all_subjects = subjects.union(broader_subjects)
    subject_triples = df[df['head'].isin(all_subjects) | df['tail'].isin(all_subjects)]
    type_relations = df[(df['relation'] == 'rdf:type') & (df['head'].isin(direct_triples['tail']))]


    combined_triples = pd.concat([direct_triples, subject_triples, type_relations]).drop_duplicates()

    if combined_triples.empty:
        print("No relevant triples found for the given entities.")
        return None


    triples_array = combined_triples[['head', 'relation', 'tail']].values
    print(f"Number of related triples found: {len(triples_array)}")
    print(triples_array)


    triples_factory = TriplesFactory.from_labeled_triples(triples_array)

    model_kwargs = dict(embedding_dim=100)
    if model_name == 'TransH':
        model_kwargs['relation_dim'] = 50  # TransH requires relation_dim

    result = pykeen.pipeline.pipeline(
        model=model_name,
        training=triples_factory,
        validation=triples_factory,
        testing=triples_factory,
        training_kwargs=dict(num_epochs=300, use_tqdm_batch=False),
        optimizer_kwargs=dict(lr=0.1),
        model_kwargs=model_kwargs,
    )


    model = result.model

    entity_embeddings = model.entity_representations[0](indices=None).detach().cpu().numpy()

    id_to_entity = {v: k for k, v in triples_factory.entity_to_id.items()}

    entity_embedding_dict = {}

    for entity in target_entities:
        entity_id = triples_factory.entity_to_id.get(entity)
        if entity_id is not None:
            entity_embedding = entity_embeddings[entity_id]
            entity_embedding_dict[entity] = entity_embedding
            print(f"Embedding for {entity}: {entity_embedding[:5]}...")
        else:
            print(f"Entity {entity} not found in the trained model.")

    return entity_embedding_dict


entity_embeddings = generate_embeddings("dbpedia_irish_places_triples_v2.tsv", populated_places, model_name='RotatE')
# Out:
# WARNING:pykeen.pipeline.api:No random seed is specified. Setting to 1719623161.
# WARNING:pykeen.utils:No cuda devices were available. The model runs on CPU
# INFO:pykeen.pipeline.api:Using device: None
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# INFO:pykeen.nn.representation:Inferred unique=False for Embedding()
# Number of related triples found: 2825
# [['http://dbpedia.org/resource/Holywell,_Swords' 'rdfs:label'
#   'Holywell, Swords']
#  ['http://dbpedia.org/resource/Holywell,_Swords' 'dbo:abstract'
#   "Holywell (Irish: Tobar Naofa) is a neighbourhood near Swords, Dublin, Ireland. Developed and marketed in phases and under various names, Feltrim Hall, Gorse Hill, Abbey Stone, Holywell and The Meadows, all the street names in the community include the common name Holywell e.g. 'Holywell Drive'. It is the eastern part of the census town of Kinsealy–Drinan, separated from the western part by the M1 motorway."]
#  ['http://dbpedia.org/resource/Holywell,_Swords' 'dbo:country'
#   'http://dbpedia.org/resource/Republic_of_Ireland']
#  ...
#  ['http://dbpedia.org/resource/City_status_in_Ireland' 'rdf:type'
#   'http://dbpedia.org/ontology/Place']
#  ['http://dbpedia.org/resource/Capital_city' 'rdf:type'
#   'http://dbpedia.org/ontology/City']
#  ['http://dbpedia.org/resource/Capital_city' 'rdf:type'
#   'http://dbpedia.org/ontology/Settlement']]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Training epochs on cpu:   0%|          | 0/300 [00:00<?, ?epoch/s]
# WARNING:pykeen.utils:Using automatic batch size on device.type='cpu' can cause unexplained out-of-memory crashes. Therefore, we use a conservative small batch_size=32. Performance may be improved by explicitly specifying a larger batch size.
# Evaluating on cpu:   0%|          | 0.00/2.83k [00:00<?, ?triple/s]
# WARNING:torch_max_mem.api:Encountered tensors on device_types={'cpu'} while only ['cuda'] are considered safe for automatic memory utilization maximization. This may lead to undocumented crashes (but can be safe, too).
# INFO:pykeen.evaluation.evaluator:Evaluation took 37.87s seconds
# Embedding for http://dbpedia.org/resource/Holywell,_Swords: [ 1.999136  +2.0390997j  0.84975123+2.4695225j  1.22292   +1.6114016j
#  -3.976648  +1.3584534j  0.71216094+1.1501954j]...
# Embedding for http://dbpedia.org/resource/Leyny: [ 4.182246 +4.1992292j   3.3957686+2.2061894j  -0.9555179-3.0078902j
#   3.0175092+0.66954017j -2.1532474-4.3345103j ]...
# Embedding for http://dbpedia.org/resource/County_Cavan: [ 0.02907994-0.02442312j  1.6273282 -0.28416654j  2.1518743 +2.1167235j
#  -2.216592  -1.6800848j   3.5918205 +1.4456336j ]...
# Embedding for http://dbpedia.org/resource/County_Cork: [-1.9195461-2.0918083j   1.1118373-0.21020867j  2.9342036+1.8075879j
#  -5.074683 +1.1959394j   1.5442896+2.4558487j ]...
# Embedding for http://dbpedia.org/resource/County_Galway: [-4.067013 +0.48516747j  5.7840443-3.7350833j   3.023813 +1.2288835j
#  -4.2155676-2.8274267j   2.7771816+1.7734277j ]...
# Embedding for http://dbpedia.org/resource/County_Kerry: [-6.15366   +2.6632297j  3.3320742 -2.1827073j  0.49367145-1.7439214j
#  -2.8038442 -1.2730826j -2.8174212 +2.8421278j]...
# Embedding for http://dbpedia.org/resource/County_Kilkenny: [-2.5947087 -0.0349693j  2.9729161 -2.9247966j  1.7697767 -0.8443179j
#   0.05627357-2.4374228j -1.5482882 -2.5687275j]...
# Embedding for http://dbpedia.org/resource/County_Laois: [ 0.3037075 +1.5141605j   2.4108827 +0.35681516j -0.09819135-2.3238604j
#  -2.5082033 +6.971898j    1.477154  +0.24898325j]...
# Embedding for http://dbpedia.org/resource/County_Leitrim: [ 2.128934 -3.042832j   4.033174 -1.8365299j -1.8265836-1.7631879j
#  -3.8106241+3.1023629j  2.689547 +2.6875596j]...
# Embedding for http://dbpedia.org/resource/County_Louth: [-5.089653 +0.07023165j  4.8949313-0.4494199j  -1.0323514-1.1850489j
#   2.928341 +1.1540991j  -1.5398268+1.7791653j ]...
# Embedding for http://dbpedia.org/resource/County_Mayo: [-2.9050555 +0.40939042j  1.9049337 -0.43985063j -1.1136914 -2.4069397j
#   3.5227308 -3.4923766j  -0.26574877+3.8204427j ]...
# Embedding for http://dbpedia.org/resource/County_Meath: [-4.456252 +5.3571444j   2.542966 -5.5505595j   5.4872713+2.1631305j
#  -3.5657797+3.032787j   -0.5588666-0.10688929j]...
# Embedding for http://dbpedia.org/resource/County_Offaly: [ 0.9244417-1.5221161j   5.927711 -2.1060596j   3.0146165-1.8146943j
#  -0.5580282+2.1411266j   0.7702405-0.06663898j]...
# Embedding for http://dbpedia.org/resource/County_Sligo: [-3.7461908+1.4641068j  5.8188596-0.5441012j  2.9655051-1.3226043j
#   4.349672 -0.1606802j -0.633625 +1.4770577j]...
# Embedding for http://dbpedia.org/resource/County_Tipperary: [-2.8945708 -2.357266j    1.9653704 +1.3414533j   1.5807614 -0.5436633j
#  -3.9349837 -1.6053672j  -0.24377736-0.26580745j]...
# Embedding for http://dbpedia.org/resource/County_Waterford: [-4.514807 +1.409918j    1.2546722-2.7024887j   1.4665489+1.2269889j
#  -1.7174853-1.7786181j   1.6785917-0.06223686j]...
# Embedding for http://dbpedia.org/resource/County_Westmeath: [-2.9455428 -2.629298j   3.418223  -3.3802483j  1.1879965 +3.61576j
#  -2.430621  -1.9470048j  0.12839194-4.0111604j]...
# Embedding for http://dbpedia.org/resource/County_Wexford: [-4.3800306 +3.6954448j  2.2182925 -6.6272373j  3.6834946 -1.4149188j
#  -2.9804454 -2.927215j  -0.09584656-3.9355714j]...
# Embedding for http://dbpedia.org/resource/County_Wicklow: [-1.3937366+5.3702426j   5.774097 +0.6779951j   4.3861666-0.21315603j
#   1.0334909-2.3087475j   1.5699594-0.8399121j ]...
# Embedding for http://dbpedia.org/resource/Ráth_Chairn: [-2.424645 +0.75415736j  2.9594128+1.1587381j  -4.062342 -3.6268373j
#   4.300682 -1.1450747j   2.4697592-2.1255622j ]...
# Embedding for http://dbpedia.org/resource/Erris: [ 5.009472 +3.750878j   4.6750884+5.936599j   3.1709204-0.8386439j
#   4.1499667+3.2968776j -4.8491945-1.387119j ]...
# Embedding for http://dbpedia.org/resource/Tireragh: [ 3.2965274+8.378422j  -0.4473963+5.9798126j  0.1056518-1.7404978j
#   3.6129868+3.3963501j -3.8714464-3.6832743j]...
# Embedding for http://dbpedia.org/resource/Effin: [-0.94258106+2.94087j    -0.86944264+1.699797j   -2.4111829 -0.6843245j
#   0.23663117-1.6304728j  -1.8688443 +0.56414837j]...
# Embedding for http://dbpedia.org/resource/Galway: [ 3.799231  -0.12862015j  0.11877809-3.5587182j   0.9371308 +2.4935634j
#  -5.7014036 +0.23593745j  1.5169525 +2.854313j  ]...
# Embedding for http://dbpedia.org/resource/Cloughjordan_Ecovillage: [-1.6745168 +4.8830705j  0.66619843+5.5747757j -1.5688295 +1.8376416j
#   2.9807081 +2.8076627j  2.0939546 -1.4424912j]...
# Embedding for http://dbpedia.org/resource/Caher_Island: [ 3.5898104 +2.0941381j  0.13221312+7.990053j   4.848769  +3.6827517j
#  -0.52053374+6.3584757j -3.3163915 -3.129773j ]...
# Embedding for http://dbpedia.org/resource/Cahir: [-4.3440156-1.8323439j -1.4082835-5.1762667j -6.225654 +1.2331114j
#  -1.0178233+2.2867675j  3.7673144+6.7413707j]...
# Embedding for http://dbpedia.org/resource/Canon_Island: [-6.6540236 +5.4261713j  -2.338042  +1.8547347j   3.2714036 +0.32113776j
#  -1.5646478 -1.2316219j   0.75227636+2.764657j  ]...
# Embedding for http://dbpedia.org/resource/Cape_Clear_Island: [-3.2012923 +4.3475842j  -1.9980358 +0.21307513j -1.8685209 -6.4351115j
#  -1.673522  -0.6187007j   0.07656098+1.123368j  ]...
# Embedding for http://dbpedia.org/resource/Capel_Island: [-2.0677714+4.6341496j -2.0112796+1.4069306j  1.3025255-2.5802712j
#  -2.9768498+2.4021895j -1.2017088-0.6671425j]...
# Embedding for http://dbpedia.org/resource/Carlow: [ 0.25630647+2.2916691j   4.3418646 -0.72143644j -2.0551534 +2.6331742j
#   0.1456744 +5.901103j    3.1623702 +3.6416817j ]...
# Embedding for http://dbpedia.org/resource/Carndonagh: [ 1.5270703+3.896014j   1.276558 -4.795819j   5.1427913+4.0946946j
#  -1.1077641-2.971368j   0.9712347+5.7826886j]...
# Embedding for http://dbpedia.org/resource/Carrick-on-Shannon: [ 6.943262 +8.455943j   7.120235 +5.0071955j -6.0714107+7.6438785j
#   1.2239351-4.114771j  -4.521767 -3.591746j ]...
# Embedding for http://dbpedia.org/resource/Carrick-on-Suir: [-0.76826966+2.3330495j  0.29746532+1.593542j  -0.6653336 -2.510525j
#   0.7068805 +1.0592448j -0.99796236+3.2824337j]...
# Embedding for http://dbpedia.org/resource/Carrigaline: [-0.28161168+2.8047535j  5.7703953 +3.5961244j -0.2866999 -6.370533j
#   0.10010526-2.9627013j -0.79114515+1.1053555j]...
# Embedding for http://dbpedia.org/resource/Carrigart: [-5.7251735+2.5079124j  -1.8586355+4.592876j   -5.491297 -1.3930483j
#   1.2707456-0.06103176j -8.798674 -1.5722095j ]...
# Embedding for http://dbpedia.org/resource/Carrigtwohill: [ 2.3026218 +4.163932j    0.54529864-0.199456j   -1.0130017 -2.9364266j
#   0.5931052 -0.58182836j -0.81419915+1.8049413j ]...
# Embedding for http://dbpedia.org/resource/Cashel,_County_Tipperary: [-0.33786368+4.468542j   6.170045  +1.0712912j  4.568904  -1.3058914j
#   0.89095134-2.2723293j -5.629     +3.2614996j]...
# Embedding for http://dbpedia.org/resource/Castletownshend: [ 4.1764607+4.69563j   -1.9055122+4.920416j   3.142297 -2.4930804j
#  -1.0166838+4.1093454j -4.6502295+4.6172004j]...
# Embedding for http://dbpedia.org/resource/Castletroy: [-2.2217114 +1.9146649j  5.9539824 +3.3691187j -0.93551224-3.5092347j
#  -0.5250141 +2.5432868j  3.0645194 -2.4402523j]...
# Embedding for http://dbpedia.org/resource/Puffin_Island_(County_Kerry): [-4.601209  +1.1027347j -7.526307  +3.523312j   2.8670547 -1.6284512j
#  -2.690956  -1.8473935j -0.02474101+3.9316735j]...
# Embedding for http://dbpedia.org/resource/Quilty,_County_Clare: [ 2.9530284+5.887872j    1.9208902+0.6860785j   1.4399397+0.78142035j
#  -2.7771096+0.27026683j -2.4870253-0.6663382j ]...
# Embedding for http://dbpedia.org/resource/Roscommon: [-2.9952555+1.9135201j  3.403927 +3.8801694j -5.479727 +4.240473j
#   1.1778067+5.238414j  -2.9853008+3.0772693j]...
# Embedding for http://dbpedia.org/resource/Rossmore_Island: [-3.2732813+5.4501586j  -3.8388665+2.398026j   -2.3138335+0.3241744j
#   1.5578841-0.65331066j  3.2512987+2.152576j  ]...
# Embedding for http://dbpedia.org/resource/Rotten_Island: [-5.0512047+0.5188903j -0.6851   +3.0664854j -0.4394619-1.1478199j
#  -1.1275383+4.575488j  -3.655008 -4.286732j ]...
# Embedding for http://dbpedia.org/resource/Beginish_Island: [-2.823016 -0.82721424j -3.252786 +3.0246139j   0.6508049-0.21435936j
#  -3.6332273+1.9311713j  -3.7309768+0.12020507j]...
# Embedding for http://dbpedia.org/resource/Beiginis: [ 4.5445156+2.0077105j -2.438716 +4.2564816j -1.7525651+2.9057071j
#  -2.6287684+2.7285903j  1.5037676+3.2445135j]...
# Embedding for http://dbpedia.org/resource/Belmullet: [ 2.8024971-0.6045442j -5.098647 +7.050108j   1.4640338-4.396292j
#   4.2766194+6.5450826j -1.0256968-1.9120944j]...
# Embedding for http://dbpedia.org/resource/Bere_Island: [ 2.0443273 +7.3936048j -3.3460755 -0.9994772j -0.23226836-0.7881198j
#  -3.1337924 +2.0281107j -3.8069081 +0.8648728j]...
# Embedding for http://dbpedia.org/resource/Borrisoleigh: [-2.6976478 +0.5537522j   3.8594334 -0.88209456j -4.042541  +2.1090322j
#   0.09861567+4.816159j    1.5640078 +2.3430238j ]...
# Embedding for http://dbpedia.org/resource/Bray,_County_Wicklow: [-0.925863  +3.9465027j   5.276591  +1.1487665j  -4.577262  -0.36148506j
#  -0.39609638-0.59928435j -1.1365443 +1.425623j  ]...
# Embedding for http://dbpedia.org/resource/Deenish_Island: [-2.3099513+2.5954952j  1.6585327+0.8068879j  0.6876287+2.486753j
#  -0.749408 +0.5325203j -3.0241632-1.1966721j]...
# Embedding for http://dbpedia.org/resource/Deer_Island_(Ireland): [ 0.690832  +2.6716576j  1.2763759 +4.3946238j  0.33714932+0.7505166j
#  -4.4116793 +5.244013j   2.0340104 -2.8432724j]...
# Embedding for http://dbpedia.org/resource/Howth_Head: [ 2.7991366 +1.968731j  -3.6870646 -3.5395594j -2.7543354 -1.5127559j
#  -0.12052491-3.3144722j  1.8697172 -2.7195427j]...
# Embedding for http://dbpedia.org/resource/Little_Skellig: [ 0.54299486+2.5200813j -5.123154  +2.347892j   3.1172464 -2.0254257j
#  -5.0083156 +2.2725873j -5.422059  +4.3230205j]...
# Embedding for http://dbpedia.org/resource/Riverchapel: [ 0.19099027-2.0127795j  3.9427478 -1.8678408j -3.2046206 -2.4236798j
#  -1.5804045 +2.019675j  -1.3588845 +2.7878995j]...
# Embedding for http://dbpedia.org/resource/Rivermeade: [-0.33988094-0.9280665j   1.8535186 +2.4192843j  -5.2801294 -5.05962j
#  -0.5264151 -0.79580724j  4.949392  +1.4091797j ]...
# Embedding for http://dbpedia.org/resource/Roancarrigmore: [-0.07433929+6.3395586j -1.557513  -1.7148194j -0.03406549-2.4500694j
#  -6.748891  -2.8688126j -0.532071  +2.8810637j]...
# Embedding for http://dbpedia.org/resource/Ulster: [ 0.29256466+2.833733j   -5.3916492 -3.4412222j   1.1149908 +3.2274003j
#   1.6123868 -0.67473835j  2.3076441 -2.0354562j ]...
# Embedding for http://dbpedia.org/resource/Upperchurch: [1.119211 +5.651203j  3.2197225-1.7817401j 3.4112859-3.626388j
#  1.0350527-3.594013j  1.6084533-3.3109097j]...
# Embedding for http://dbpedia.org/resource/Valentia_Island: [-2.682383 +5.1892996j -4.109995 +5.4482765j  1.6566956-0.379592j
#   2.1802623+3.6120327j  5.12422  -1.4992744j]...
# Embedding for http://dbpedia.org/resource/Ventry: [-1.4901795+4.4999914j -5.306478 +6.0736656j  5.5788527-5.1559763j
#   2.5950136-1.0740901j  2.1487346-2.7166684j]...
# Embedding for http://dbpedia.org/resource/East_Meath: [ 0.8565477 +3.2999651j  0.59948856-2.1982553j -4.1470113 -0.326511j
#   0.4095046 +4.6355295j -4.167652  -1.2929537j]...
# Embedding for http://dbpedia.org/resource/Colt_Island: [ 1.8357338+4.928064j  -2.3826904+2.3378468j -2.3053608+2.6657891j
#  -3.6876397+6.0623655j  1.4904608+1.2548513j]...
# Embedding for http://dbpedia.org/resource/Coney_Island,_County_Sligo: [ 6.343413 +4.2331667j  -2.1108875-0.82686377j -0.8247231+2.809697j
#  -1.2182572-4.9082174j  -4.4265575+1.8770182j ]...
# Embedding for http://dbpedia.org/resource/Connacht: [-2.0255795+1.3721623j   4.2410355-2.9316182j   2.4472456+0.96453863j
#   1.9822464-0.8500598j   2.888133 -1.0816479j ]...
# Embedding for http://dbpedia.org/resource/Coolkenno: [-3.3289042-0.69695973j  3.4621842+2.5119324j  -2.584794 -4.533849j
#  -4.163436 +5.427326j    4.025317 +1.9906904j ]...
# Embedding for http://dbpedia.org/resource/Cork_(city): [ 4.893188 -0.38068652j  1.1728988-1.9251457j   3.3133178+5.5393353j
#  -3.6442814-1.1537502j  -2.855456 -0.5317555j ]...
# Embedding for http://dbpedia.org/resource/Cortober: [-1.7250571 +6.1969585j  2.1587617 +3.3544586j -1.7986203 +3.5928051j
#   2.1694396 +1.7133378j  0.02372993+0.6341961j]...
# Embedding for http://dbpedia.org/resource/County_Longford: [ 1.34862   +6.6665406j   4.6420684 -0.3409519j   5.27916   -2.564098j
#   0.67449313+2.0461705j  -3.5312371 +0.51609385j]...
# Embedding for http://dbpedia.org/resource/Courtmacsherry: [ 0.95464116+4.198683j   5.9747753 +1.1559194j -3.1682801 -7.008146j
#  -1.7194841 +1.6841203j -4.2305436 +2.4368024j]...
# Embedding for http://dbpedia.org/resource/Courtown: [-0.4068705-0.09853256j -1.7159182-3.0347877j  -2.3658917-0.65474355j
#   0.9223493+3.8917315j  -5.143043 +2.825517j  ]...
# Embedding for http://dbpedia.org/resource/Cratloe: [ 3.1827443+6.2228756j -2.2366705+4.182431j  -3.1082962+3.6608908j
#  -1.9893715+2.2646875j -1.7249752+2.014455j ]...
# Embedding for http://dbpedia.org/resource/Crookhaven: [-0.88971674+1.1536062j -3.0136013 -0.4491696j -2.1314855 -3.3789837j
#   2.238412  -1.9402882j -3.5481637 -1.9138653j]...
# Embedding for http://dbpedia.org/resource/Crossakiel: [-2.277491  +8.946196j    1.5074421 -1.8974329j   0.8184275 -2.6314085j
#  -0.32553288-6.0255356j  -2.939751  -0.89638704j]...
# Embedding for http://dbpedia.org/resource/Cruagh: [-1.8279933+0.09159519j  1.9582555+2.5791025j  -0.8470591+4.132571j
#   3.792269 -0.5162396j   1.9224008+0.729397j  ]...
# Embedding for http://dbpedia.org/resource/Mason_Island: [-1.2217517+7.981628j  -2.018957 +6.7588787j  3.6697133-1.2701474j
#  -1.4525605-4.7437816j -2.3926048+3.6674504j]...
# Embedding for http://dbpedia.org/resource/Maínis: [-0.9395777 +3.5536125j  -5.2918363 +0.31299785j -0.13350685-0.89144367j
#  -0.4923186 +2.787153j    2.0896013 +6.4436955j ]...
# Embedding for http://dbpedia.org/resource/Rutland_Island,_County_Donegal: [ 4.4793372e+00+6.108376j   1.0748669e+00+6.11436j
#   7.3925620e-01+1.4613364j -6.4626594e+00+1.5678766j
#  -4.0461384e-03-3.866411j ]...
# Embedding for http://dbpedia.org/resource/Saggart: [ 1.8977915-1.0230447j -1.1973169-7.3162055j  0.5399639+5.2383585j
#  -0.9513058+5.0752892j  2.4757993-2.903239j ]...
# Embedding for http://dbpedia.org/resource/Saltee_Islands: [ 1.0078452+2.9581332j  -0.8122701+2.9275823j  -1.9457753+0.77941054j
#  -0.792375 -0.36902255j  3.026235 +4.682785j  ]...
# Embedding for http://dbpedia.org/resource/Clane: [-2.204406  +4.314722j  -1.4821622 +2.565662j  -2.9769614 +1.4890084j
#  -1.995605  +5.594458j  -0.80912834+3.6477876j]...
# Embedding for http://dbpedia.org/resource/Clashmore: [-4.539541  +2.1063998j  0.21624352-2.9037097j  3.628005  +4.5421963j
#  -1.0173335 +2.0485942j -3.3387961 +2.2348785j]...
# Embedding for http://dbpedia.org/resource/Cloghane: [ 2.7872162+1.0643963j  -8.067743 -1.9763222j  -1.2831936-6.3396688j
#   1.2134635-0.02081798j  0.5775343-1.5156872j ]...
# Embedding for http://dbpedia.org/resource/Clondulane: [ 1.4965456+0.23273751j  7.484009 +2.022371j   -1.6689426-6.312888j
#   2.6604805-0.54345214j -5.171696 -0.4641832j ]...
# Embedding for http://dbpedia.org/resource/Clones,_County_Monaghan: [ 2.021124  +2.559032j   -0.24848787-2.2952862j   0.41717514+0.8137364j
#   0.5690598 +0.41942102j  0.06947011-0.8185918j ]...
# Embedding for http://dbpedia.org/resource/Clonmel: [ 1.0700219+1.2203836j  -1.30215  +0.82701164j  2.1497514+1.3759458j
#  -2.6826909+1.4401318j   1.7498754+2.2834203j ]...
# Embedding for http://dbpedia.org/resource/Cloonboo: [-2.7843764+3.1151526j  -0.7559981-2.6233735j  -0.7650171-4.2912736j
#   1.764291 -1.4369963j  -2.9932668+0.86949193j]...
# Embedding for http://dbpedia.org/resource/Cloyne: [-2.9747853+0.6502419j   2.083728 -1.155132j   -2.489805 -1.0408605j
#   2.5723011+0.44197053j -1.4030964+3.8189526j ]...
# Embedding for http://dbpedia.org/resource/Cobh: [-2.6615477-2.0293303j  7.036396 +2.1574748j -1.0683281-1.1951406j
#  -2.3057497+2.8543887j -6.4064517+6.5081277j]...
# Embedding for http://dbpedia.org/resource/Collanmore_Island: [-2.8068488 -2.6378717j  -0.74370337-1.7809885j  -0.15175545+4.9749365j
#  -3.572085  -0.69619966j  2.7596867 -3.269722j  ]...
# Embedding for http://dbpedia.org/resource/Eighter_Island: [-0.7247879+5.4486156j  -4.716565 +3.8803008j   3.5107493-1.9747669j
#   0.521801 -0.11457735j  1.377805 +3.4681208j ]...
# Embedding for http://dbpedia.org/resource/Emly: [ 2.11245  +3.31839j    2.5995576-2.908156j  -2.2943509-1.6668044j
#  -3.9787574-1.813251j   1.2080564-2.56021j  ]...
# Embedding for http://dbpedia.org/resource/Enniscorthy: [-1.2572681 +1.3419448j  0.59391695+2.3131955j  0.5589214 +0.7770847j
#   0.04920277+4.074169j   3.647227  -3.6646893j]...
# Embedding for http://dbpedia.org/resource/Furnace_Island: [ 3.787461  +5.7983813j  -2.400207  -2.1461632j  -0.69884896-0.10359903j
#   1.5858757 -1.3889234j   5.050214  -3.3760288j ]...
# Embedding for http://dbpedia.org/resource/Coolavin: [-0.70192206+5.7165494j  2.6587214 +4.4074244j  0.42832473-4.1238112j
#  -0.6209125 +2.368166j   1.7275236 +1.0717753j]...
# Embedding for http://dbpedia.org/resource/Dublin: [ 2.3353498 -2.4779263j   2.2894897 -2.6031117j  -0.68503547+0.21282986j
#   1.1556404 -3.5696974j   2.0274792 -2.5021257j ]...
# Embedding for http://dbpedia.org/resource/Dún_Laoghaire–Rathdown: [-4.0607705 -2.7155514j   0.07888865-3.1396394j  -2.2868788 -1.8507j
#  -5.387105  -2.298221j    1.9061131 -0.68283445j]...
# Embedding for http://dbpedia.org/resource/Carbury,_County_Sligo: [ 3.2338688 +5.8460913j  2.505997  +3.548502j  -3.1815212 +0.9447566j
#   5.747768  +5.4505477j  0.74495685+2.3569822j]...
# Embedding for http://dbpedia.org/resource/Gubbarudda: [-0.89441603+5.51282j   -0.10379358+4.8411827j -0.10044016-0.5317989j
#   1.3577594 +2.9259157j  1.6972841 -0.902013j ]...
# Embedding for http://dbpedia.org/resource/Goresbridge: [-3.8230655+1.1823987j  5.2358446-1.9423641j  3.969021 +0.7672647j
#  -2.4855397+1.5913723j  1.6185296+4.827962j ]...
# Embedding for http://dbpedia.org/resource/Drogheda: [-0.2773548-2.9136422j  1.015916 +1.5073543j  1.1214082-2.0880105j
#   2.7386496+3.6951177j -6.00339  +1.3517909j]...
# Embedding for http://dbpedia.org/resource/Garristown: [ 5.555203  +1.5747012j  -7.055818  +6.524638j    1.9612248 -0.40831128j
#  -0.23172377-1.8055024j   5.5151997 +1.6673045j ]...
# Embedding for http://dbpedia.org/resource/Glashedy: [ 0.4015353+2.203747j    1.2643878+2.8167815j   1.349353 +0.62186503j
#  -2.5231743+2.9627512j   1.1575453+0.43126753j]...
# Embedding for http://dbpedia.org/resource/Gola_Island: [ 0.43262818+5.6833105j   1.0266169 -0.97257054j  0.40030044-2.429637j
#  -2.7378197 -2.6733525j  -2.1913505 -2.9419675j ]...
# Embedding for http://dbpedia.org/resource/Gorumna: [ 1.6747108+5.887127j   -4.3652596-4.2013793j  -2.3934722+0.01195818j
#  -3.5731826+0.22288245j  2.2914817-2.144035j  ]...
# Embedding for http://dbpedia.org/resource/Great_Blasket_Island: [ 0.54447484+1.6625017j -4.624653  +4.62076j    3.5358167 +2.5142279j
#  -2.634863  +2.9530718j -2.6409438 -1.3772794j]...
# Embedding for http://dbpedia.org/resource/Great_Island: [-4.7440248+4.8927083j  1.7235459-3.0325265j  5.0053906-1.8026817j
#  -2.7593296-1.0047277j -4.9036803+1.8434632j]...
# Embedding for http://dbpedia.org/resource/Monasterevin: [-1.862315  +6.1541004j -2.6563566 +7.1237507j  0.27624178-1.6690192j
#  -0.8891828 +2.6598597j -2.549056  +5.006547j ]...
# Embedding for http://dbpedia.org/resource/Mornington,_County_Meath: [-5.004487 +3.0160944j  3.306905 +1.2950021j  2.213883 -3.1127636j
#   1.6593964-1.7452452j -1.3170913+1.6266104j]...
# Embedding for http://dbpedia.org/resource/Mountcharles: [ 1.9071838 +6.790537j  -1.3693278 -0.1781003j -0.21258311-0.6093424j
#  -4.4602456 -3.607379j  -3.0574102 -2.5018675j]...
# Embedding for http://dbpedia.org/resource/Mullaghmore,_County_Sligo: [-6.6305184+7.7741117j -3.1877098+2.766914j  -2.8788671-6.902521j
#   2.1881645+3.8883138j -3.2040823+4.7994733j]...
# Embedding for http://dbpedia.org/resource/Mullaghmore_Peninsula: [-2.518387  +6.4831085j -4.915363  -4.318571j   2.0327187 -1.5365642j
#   0.78323764-0.4359982j -1.5397654 -1.0917153j]...
# Embedding for http://dbpedia.org/resource/Mulranny: [ 2.8458936 -1.909852j   -0.81657714+0.06630351j  2.7140312 -2.7155485j
#   1.286597  +3.6193824j  -0.09612104+2.2240477j ]...
# Embedding for http://dbpedia.org/resource/Munster: [2.946841  +4.529047j   5.5045986 -5.4789476j  0.25125495+5.7545533j
#  3.5320332 -0.05457582j 3.8242369 -2.3914075j ]...
# Embedding for http://dbpedia.org/resource/Mutton_Island: [-0.00297686+3.1962607j  0.40195438+0.6851451j  0.91309017+5.6492434j
#  -0.35432366+6.622241j   2.6746712 -3.3941774j]...
# Embedding for http://dbpedia.org/resource/Mutton_Island,_County_Galway: [-1.2075977+3.8213913j  -1.7466788+3.0637338j  -0.9557381+1.0670809j
#   2.4761367+0.24278377j -0.9935855-0.18305808j]...
# Embedding for http://dbpedia.org/resource/Coolera_Peninsula: [-1.0362098 +5.265897j  -6.4026823 -4.6691427j  0.98551476-1.7692238j
#  -2.1040137 -1.7114522j  1.5206412 -0.2581789j]...
# Embedding for http://dbpedia.org/resource/Thomastown: [ 0.03386712+4.0813804j  2.7356987 +1.1754651j  5.803894  +6.5948043j
#  -0.21571828+1.7009228j  0.06233484+4.8025064j]...
# Embedding for http://dbpedia.org/resource/Annacotty: [ 0.4789253 +1.1431876j  2.9238405 -2.2059526j  0.06409206-0.4487242j
#   3.2615807 +6.6427293j -0.69901836-0.672869j ]...
# Embedding for http://dbpedia.org/resource/Annagry: [ 0.30109945+5.208788j   -5.6769223 -0.41878995j  2.7840376 -4.182172j
#   3.163328  +0.8662675j  -4.4625535 -3.369375j  ]...
# Embedding for http://dbpedia.org/resource/Leinster: [-2.242684  +8.064279j   0.6787287 -3.59105j    0.39813575+1.9881879j
#   0.94319624+2.4208212j  2.880016  -1.7065647j]...
# Embedding for http://dbpedia.org/resource/Limerick: [-2.0149202 -0.8007999j  3.7571707 -2.2166076j  0.25256547-1.5263487j
#  -0.56628394+0.1499983j  3.497008  +1.3305088j]...
# Embedding for http://dbpedia.org/resource/Long_Island,_County_Cork: [-0.9666686+7.03202j    1.6847644+1.7304984j  2.0185122-2.2930164j
#   1.4402117-2.0727978j -2.3762858-1.4438974j]...
# Embedding for http://dbpedia.org/resource/Lusk,_Dublin: [ 0.9086113 -0.9153619j  -0.38183975-0.17104605j  0.7175811 +1.2382903j
#  -0.6778472 -2.1254652j   6.9595327 -4.0490437j ]...
# Embedding for http://dbpedia.org/resource/Lyre,_County_Cork: [ 3.755741 +6.2822695j -0.3840634+3.9698734j  2.78135  -2.0358317j
#  -0.7083461-1.429001j  -0.5009447+5.8859935j]...
# Embedding for http://dbpedia.org/resource/Macroom: [-0.79120696+3.017404j   5.866074  +2.6787467j  1.711975  +1.4297904j
#   1.1755439 +3.21185j   -1.5178534 -0.3707392j]...
# Embedding for http://dbpedia.org/resource/Magharee_Islands: [-0.47177786+5.9769564j -2.4941623 +2.987143j   1.1594577 -3.1166863j
#  -4.506694  +3.3176355j  1.1395495 -0.8964965j]...
# Embedding for http://dbpedia.org/resource/Malin,_County_Donegal: [-4.0113187+0.5555779j  -3.6671202-3.9727347j  -2.22421  +4.575808j
#  -4.123242 -0.49553236j -2.1158848+7.029436j  ]...
# Embedding for http://dbpedia.org/resource/Malin_Beg: [-0.38960856+6.07573j    3.7147937 +2.7226965j -2.2251792 -3.9156187j
#   0.8363962 -4.1110063j -2.3399863 -0.0257985j]...
# Embedding for http://dbpedia.org/resource/Skellig_Islands: [ 0.4979696-1.9004097j  -2.3953538+5.750997j    1.6267974-3.5663512j
#   2.9040406+0.12145803j -2.80643  +2.1548502j ]...
# Embedding for http://dbpedia.org/resource/Skibbereen: [-0.02005083+1.657913j  -2.503909  +3.0774746j -1.1518222 +1.5520625j
#  -3.6372387 -1.7006897j  6.175551  +6.883428j ]...
# Embedding for http://dbpedia.org/resource/St_Patrick's_Island: [-1.9727155+1.340176j   -3.3382812+4.230401j   -0.3460816+2.3174384j
#  -3.5976672+4.6910563j   1.5374857-0.59352976j]...
# Embedding for http://dbpedia.org/resource/Strade: [ 0.72762537+2.5460844j   0.85089725+3.9682739j   3.1825578 -3.4255664j
#   3.1017642 +0.49778602j -2.8051076 -0.15055956j]...
# Embedding for http://dbpedia.org/resource/Streamstown,_County_Westmeath: [-3.4109147+5.3691645j  0.6916168-2.0432236j  2.8954682-1.7466702j
#   1.1191251+3.500812j   1.6913285+4.8925657j]...
# Embedding for http://dbpedia.org/resource/Maugherow_Peninsula: [-0.6872791 +5.415695j  -0.15587334-3.2819734j  3.0792973 +4.024644j
#  -2.2027788 +1.9852895j -3.094477  +4.85212j  ]...
# Embedding for http://dbpedia.org/resource/Baile_Ghib: [-2.6302428+3.3941188j -2.9495425+3.3912487j -2.965368 +2.7495875j
#   1.518914 +2.0848193j  0.4518648-1.143959j ]...
# Embedding for http://dbpedia.org/resource/Balbriggan: [-1.3837726-4.2774696j  -1.3364948+0.74024236j -2.810033 +0.34276354j
#  -3.9437292-2.6512892j   4.612936 +4.314008j  ]...
# Embedding for http://dbpedia.org/resource/Balla,_County_Mayo: [ 0.9779487 +7.2902465j   2.6013093 -0.9684656j   5.638029  -0.05834643j
#  -0.68967843+2.5018873j   1.543279  +1.7579317j ]...
# Embedding for http://dbpedia.org/resource/Ballinabranna: [-2.1389508+2.6533635j -3.5189278+2.2808185j -3.7934222-2.9876451j
#  -4.9989657+2.7279294j  4.731632 -4.0508327j]...
# Embedding for http://dbpedia.org/resource/Ballinaclash: [ 1.359454 +4.5688825j  1.5850779+1.712368j   2.8750842-3.4158456j
#  -1.0134231-1.7071882j -0.7144528-0.907651j ]...
# Embedding for http://dbpedia.org/resource/Ballinamore: [ 1.2565258 +1.0352292j   0.8102404 -0.19489253j  0.88687164-1.2222804j
#  -0.18524814+2.9646401j  -2.713626  +2.6284072j ]...
# Embedding for http://dbpedia.org/resource/Ballindine: [ 1.7809883+3.757655j   4.4296546+0.9344583j  1.5030258-4.7408414j
#  -1.7385664+1.4976933j  2.2855346+4.1759768j]...
# Embedding for http://dbpedia.org/resource/Ballinroad: [-2.912132  +1.3975557j  1.1845934 -2.7524707j -0.16934513-1.6693552j
#   0.39119962-1.2063444j -2.1645732 -1.9391433j]...
# Embedding for http://dbpedia.org/resource/Ballinskelligs: [-6.5316753 +3.8258445j -8.496568  -0.7492716j  0.01923083-4.9236693j
#  -3.8793514 -3.753358j  -1.5323921 +1.8794557j]...
# Embedding for http://dbpedia.org/resource/Ballivor: [-2.1289475+5.956045j  -3.0847178-0.5116048j  2.3227966-1.3701419j
#  -2.600037 +2.7359614j -2.5599456+4.3587337j]...
# Embedding for http://dbpedia.org/resource/Ballybay: [ 3.4362774-4.0874233j  6.7684317+0.2639501j  0.5563219+1.9331652j
#  -1.5700585-1.366614j   1.29245  +3.3570304j]...
# Embedding for http://dbpedia.org/resource/Ballycannan: [-4.195658 +3.2646697j  -3.3729498+0.05567354j -1.8773665+2.275072j
#   2.6899626+4.055389j    2.842057 +4.34534j   ]...
# Embedding for http://dbpedia.org/resource/Ballycotton: [-3.1601274 +0.9712326j   3.7011945 -0.41557875j -3.465728  -5.0821366j
#  -1.2794299 +1.3049561j  -0.20779538-5.35076j   ]...
# Embedding for http://dbpedia.org/resource/Ballyhaunis: [-5.0740767 +1.122873j   -3.1537619 +0.6516961j   0.0699614 -3.0334377j
#  -0.44704026+2.124161j    2.5447364 -0.95439696j]...
# Embedding for http://dbpedia.org/resource/Ballymore,_County_Westmeath: [ 3.343165 +7.79535j    4.967272 +3.3181837j  1.0227269+2.5072381j
#   2.1916358+2.3892243j -0.8640217-4.2629395j]...
# Embedding for http://dbpedia.org/resource/Ballynacargy: [ 1.9086690e+00+6.987755j    9.9259382e-01-0.13173378j
#   1.1572857e+00-2.3135805j  -4.1479990e-04+4.904372j
#   3.4998941e+00+1.1684682j ]...
# Embedding for http://dbpedia.org/resource/Ballysadare: [-1.9055369 +2.139167j  -4.840231  +2.7531934j  4.3757434 -5.7123723j
#  -4.569596  +3.685411j   0.00948291+3.8105164j]...
# Embedding for http://dbpedia.org/resource/Ballyshannon: [-3.7467437-3.4161556j  3.2676218-3.4119945j -5.0599446+2.0496068j
#   3.949979 +4.8145285j -1.8620684-2.1849418j]...
# Embedding for http://dbpedia.org/resource/Ballysheehan: [ 0.39164007+2.4599724j -0.6058976 -4.5118394j -5.826032  -5.239664j
#   1.4365071 -1.8965592j -0.235793  -1.1598935j]...
# Embedding for http://dbpedia.org/resource/Balrothery: [ 4.3422236 -2.6980076j   0.53878874+0.02837312j -2.0478544 -1.0902925j
#  -5.17687   +0.26360592j  4.220235  +0.60844505j]...
# Embedding for http://dbpedia.org/resource/Bandon,_County_Cork: [-4.2888436+0.1203234j -2.2777448+3.2489917j -2.5986178-6.579906j
#   3.6340783+2.1262665j -5.1039243+3.4981618j]...
# Embedding for http://dbpedia.org/resource/Bruff: [ 2.2259436+4.6314144j   1.6409225+1.3714991j   3.2002842+0.91719437j
#  -3.1042101+1.199304j   -2.1835155+3.5210485j ]...
# Embedding for http://dbpedia.org/resource/Bundoran: [-2.5597916-1.4724319j   2.1541991-3.5319679j  -3.650172 +1.3164307j
#   2.2210631-0.40802252j -1.901964 -0.42790776j]...
# Embedding for http://dbpedia.org/resource/Burnfoot,_County_Donegal: [-1.2761493 +2.1854115j  0.33933297+2.910767j   1.9841858 +1.6693579j
#  -6.2546573 +5.341015j  -1.6518469 +2.6385088j]...
# Embedding for http://dbpedia.org/resource/Buttevant: [ 0.74269336+3.5852184j  1.3072685 +2.4424763j  3.6414375 -0.2803215j
#  -0.3518541 +0.9602783j -2.128728  +1.6787523j]...
# Embedding for http://dbpedia.org/resource/Cavan: [-0.31101933+4.306753j  -0.27489382+0.090047j  -2.7825031 -5.0856566j
#   3.3550048 +1.4628011j -5.6378217 +1.2533435j]...
# Embedding for http://dbpedia.org/resource/Threemilehouse: [ 5.1805506+2.4795775j  0.409126 -3.8762465j  3.448998 +6.5928216j
#  -4.285022 +5.782236j   1.699456 +4.4366407j]...
# Embedding for http://dbpedia.org/resource/Tipperary_(town): [-0.2728573 +4.163309j   0.8038492 +1.2975069j -1.2868352 -1.8536497j
#   0.28283787-1.0107604j  2.1392565 +1.0925121j]...
# Embedding for http://dbpedia.org/resource/Tory_Island: [ 3.9196367+6.3482227j  -1.1202908+6.358386j   -4.2359757-1.2458237j
#   2.3966794-0.10018817j -1.6579212-1.1835182j ]...
# Embedding for http://dbpedia.org/resource/Trummer: [-0.5430336 +2.7491665j   4.845256  +3.632237j    3.0583005 -0.6300377j
#  -0.30418146+1.7949528j   3.0895247 +0.71439165j]...
# Embedding for http://dbpedia.org/resource/Tulsk: [-8.280136 +10.327543j   1.6729784 +9.352523j   2.9404593 -3.2309575j
#   1.3412734 +1.4640914j -7.503289  -4.1669464j]...
# Embedding for http://dbpedia.org/resource/Turbot_Island: [ 2.0215313+1.6026157j -1.8518078+5.7412868j  4.1265078+2.331912j
#  -4.598367 +4.136732j  -1.8517432+1.7382352j]...
# Embedding for http://dbpedia.org/resource/Turlough,_County_Mayo: [ 2.4002037+6.326046j  -3.3854046-2.677823j   0.507067 -1.0190691j
#   3.5511582+3.1766763j  5.1918073-1.0837562j]...
# Embedding for http://dbpedia.org/resource/Whitehall,_Dublin: [-3.018877  +1.574999j   -0.27827775+0.2512274j  -2.8637712 +2.5227873j
#  -0.64797765-2.369966j    7.1191955 +0.19475412j]...
# Embedding for http://dbpedia.org/resource/Wicklow: [ 4.1451   +0.8654666j  4.94642  +0.6111878j -2.1855533+3.7841432j
#  -2.4825242+1.9893891j -3.9945347-6.5758j   ]...
# Embedding for http://dbpedia.org/resource/Wilton,_Cork: [-3.5719461 +4.4586077j -1.9455581 -4.759179j  -0.14039117-1.7566891j
#   0.29649848+1.4887547j  4.941371  -1.5948527j]...
# Embedding for http://dbpedia.org/resource/Abbeyleix: [-4.7348356+3.574117j   2.2015   +1.426658j  -0.5350877-1.1560979j
#  -3.842436 +2.4674428j -3.1208143-2.5518215j]...
# Embedding for http://dbpedia.org/resource/Achill_Island: [ 1.5974165+6.0519085j  -4.0372763+4.7435875j   1.886882 -0.18915157j
#  -5.046746 +3.4414992j   3.2113097+0.36022723j]...
# Embedding for http://dbpedia.org/resource/Achillbeg: [ 1.906622  +10.057763j    0.03996069 +2.866329j
#   0.52007806 +2.6181092j   0.17418772 +0.88514775j
#  -0.45191944 -1.9734385j ]...
# Embedding for http://dbpedia.org/resource/Aghamore: [ 0.46143267+7.9383554j  -0.6574869 -1.7677293j   4.350042  -6.4955025j
#   1.1727843 -5.4367867j  -7.774687  +0.01140616j]...
# Embedding for http://dbpedia.org/resource/Aglish: [-3.17672   +4.1659718j -0.30091274-3.7019327j -2.5702472 +4.679134j
#  -1.5069213 +4.8129497j -3.8759043 +3.5954394j]...
# Embedding for http://dbpedia.org/resource/Culdaff: [-1.7082713+5.4698987j   1.3225023-1.1047261j   2.5897708-2.7240384j
#  -3.0564585+0.2508401j   0.3018757-0.55701596j]...
# Embedding for http://dbpedia.org/resource/Dalkey_Island: [-1.165778  +1.3219705j  0.78032327+2.0821316j  0.05486874-1.1723245j
#  -2.0922122 +4.3348475j -0.24905114+3.1145415j]...
# Embedding for http://dbpedia.org/resource/Dowra: [-3.0723484+3.5993817j  1.2965926+3.0301566j -5.340868 -4.058223j
#  -2.667828 -1.6756288j  0.2840758-4.0424533j]...
# Embedding for http://dbpedia.org/resource/Dromod: [-3.085592 +5.4757147j  -0.8662117-0.83956444j  1.9349461-1.8137798j
#   0.5815815-0.05157303j -1.8756813-1.1347282j ]...
# Embedding for http://dbpedia.org/resource/Drumshanbo: [-1.3066486+6.9719806j   1.3820553+4.2893553j   1.2609414-0.31123576j
#   3.6369743-2.9075892j  -3.2949507-0.12911423j]...
# Embedding for http://dbpedia.org/resource/Duncannon: [-2.1366904 +2.3312333j  -0.10772985+1.4892887j  -2.8608694 -3.176734j
#   0.43353108+0.58333224j -1.2127979 -0.84819925j]...
# Embedding for http://dbpedia.org/resource/Dunhill,_County_Waterford: [-6.9948883+3.416943j   -0.7707128+1.9706732j  -2.8194797-0.88847923j
#   2.5423043+5.640765j    1.7783391+5.425565j  ]...
# Embedding for http://dbpedia.org/resource/Dunquin: [ 5.0875516 +2.1555364j  -7.164116  -1.1583359j  -2.249393  -2.9961963j
#  -0.64355296+3.5113199j  -1.1542314 +0.96991515j]...
# Embedding for http://dbpedia.org/resource/Dursey_Island: [ 0.58200854+5.378134j    0.9176445 -3.2631083j  -3.2254388 -4.021121j
#  -4.171243  -0.72532105j -2.6624947 +1.9584421j ]...
# Embedding for http://dbpedia.org/resource/Dún_Laoghaire: [-2.2889166 -4.270861j    0.44332826+0.78158194j -6.0694075 +1.5557615j
#  -0.60382414+0.9787073j   1.5793338 -1.8295014j ]...
# Embedding for http://dbpedia.org/resource/Edgeworthstown: [-2.6968293+4.046271j   3.436438 +5.250462j   1.3721304-0.6809355j
#   1.5590549-3.615807j  -1.9448587-3.8383179j]...
# Embedding for http://dbpedia.org/resource/Fahan: [ 1.9530032 -2.9654984j -0.31120414-1.138902j   2.8142724 -5.595663j
#  -2.3294027 -1.622466j  -3.0624323 +1.1084743j]...
# Embedding for http://dbpedia.org/resource/Fedamore: [ 2.0210056 -0.72019196j -2.371795  +1.3481413j  -0.9023949 -1.4737359j
#  -1.8977201 +0.00992634j -0.96004176-0.6576292j ]...
# Embedding for http://dbpedia.org/resource/Fethard-on-Sea: [-0.8883873-0.11319491j  5.272511 +1.161997j   -4.0298657+2.2030861j
#   2.579823 -2.4173656j  -1.3773731-4.323593j  ]...
# Embedding for http://dbpedia.org/resource/Foxford: [ 1.7198601 +4.4674926j  3.626789  +3.9239652j -0.46883738-1.1585473j
#   1.9750503 +1.1781372j -1.0648601 -3.9604232j]...
# Embedding for http://dbpedia.org/resource/Owey_Island: [-0.02875677+7.068877j  -5.667406  +1.8350252j  3.9971209 -0.3388914j
#   0.9110661 +1.519586j   0.8521072 +1.2690792j]...
# Embedding for http://dbpedia.org/resource/Passage_West: [-0.76190585+2.3386152j  1.44992   -3.6337662j -4.4397173 -5.639986j
#   4.058113  +2.505856j  -0.15586513-3.0791366j]...
# Embedding for http://dbpedia.org/resource/Gweedore: [-3.7167819 +7.528503j    0.22095639+3.772007j   -3.8255327 -0.72373533j
#   2.7097645 -1.3669207j  -4.5063276 +0.54670113j]...
# Embedding for http://dbpedia.org/resource/Ireland: [-3.3229923 +3.20369j    -2.4675596 +1.0129216j   4.4151874 -0.7936109j
#   1.1839814 -1.1817075j  -0.18263648+0.65424764j]...
# Embedding for http://dbpedia.org/resource/Island_Eddy: [ 0.24858984+0.03731192j -1.8597686 +2.9910235j   2.2508395 -0.39576083j
#  -3.1913557 +6.0625114j   4.8459725 +0.25479212j]...
# Embedding for http://dbpedia.org/resource/Tallaght: [-5.039048 +0.16095522j  0.9551801+0.03379763j -1.5311908+4.220564j
#   1.5625257-0.08727055j -4.8007846+0.7898075j ]...
# Embedding for http://dbpedia.org/resource/Kilcornan: [ 0.5164959 -4.9319696j  0.12532863+0.6002711j  3.016647  +2.22755j
#  -3.8258948 -2.7904215j  1.886779  +2.7131405j]...
# Embedding for http://dbpedia.org/resource/Kilnaboy: [ 1.4259149 -0.39480698j  0.15752499+5.5642176j  -2.1969547 +0.6268062j
#   4.478733  +1.1948508j   5.2296934 +2.7350628j ]...
# Embedding for http://dbpedia.org/resource/Kilnamona: [-2.497363 +3.8080993j  -2.790904 -0.09852622j -2.9916594-1.5714592j
#   3.5790412-0.90895545j -1.8433204+6.541368j  ]...
# Embedding for http://dbpedia.org/resource/South_Dublin: [-5.663583  -1.212902j    6.059482  -3.5977557j   0.39087775+0.1312199j
#  -5.422456  +0.74772495j -1.410513  -3.1997538j ]...
# Embedding for http://dbpedia.org/resource/Tallow,_County_Waterford: [-2.3907611 +0.8939949j  1.1281345 +1.5118939j -0.06474558+2.6893318j
#  -0.4171409 +5.780277j  -1.4547361 +1.6438758j]...
# Embedding for http://dbpedia.org/resource/Tearaght_Island: [ 0.36817753-0.57850564j -5.5856175 +0.6866991j  -3.7517343 -3.0669425j
#   1.9938854 +3.02213j    -5.3653264 +2.916912j  ]...
# Embedding for http://dbpedia.org/resource/Ardnacrusha: [ 0.58374065+1.6221578j  1.7689936 +7.145307j   2.6824315 +4.3752317j
#  -1.4322265 +2.810898j  -5.61551   +0.6061524j]...
# Embedding for http://dbpedia.org/resource/Ardoileán: [-4.2782817+5.345368j    1.4049798+3.8130016j  -3.1596727-2.7645712j
#  -4.875291 +0.20838472j -0.7604137+1.9540666j ]...
# Embedding for http://dbpedia.org/resource/Arranmore: [-5.28508  +3.222639j    3.0735328+2.4308493j  -3.0661516-4.1058655j
#   0.248381 +3.6246047j  -3.5952578-0.36854988j]...
# Embedding for http://dbpedia.org/resource/Athlone: [-1.5463386 +4.445589j   2.062242  +7.0072274j  2.1397245 +2.21613j
#   2.5408924 -1.2808561j  0.56233245+1.4997132j]...
# Embedding for http://dbpedia.org/resource/Charlestown,_County_Mayo: [ 4.4134254-1.1519706j  3.338079 +5.041026j  -4.534119 -3.7952883j
#   3.6099958+2.8702195j  5.434786 -3.6785862j]...
# Embedding for http://dbpedia.org/resource/Charleville,_County_Cork: [ 1.575452 -3.8455205j  3.938524 -3.3001463j -4.1960406-4.711703j
#  -3.4579284-1.9661621j -4.162785 +3.7075403j]...
# Embedding for http://dbpedia.org/resource/Keeragh_Islands: [-3.6160507 +2.4402711j  -4.4960237 +3.7113397j  -2.1373289 -0.91246516j
#  -5.479511  -1.9088254j  -0.73329264+5.549984j  ]...
# Embedding for http://dbpedia.org/resource/Keshcarrigan: [-3.4611237+2.9812033j  2.6364617-1.1117016j  1.3709803-1.3388091j
#   0.7719312-1.3311357j -0.5106941-0.2750309j]...
# Embedding for http://dbpedia.org/resource/Kilcock: [-0.51829565+1.980195j  -3.5650964 +4.162678j  -4.823069  +1.9283463j
#   5.1839876 +3.5844824j  0.16578124+0.33678j  ]...
# Embedding for http://dbpedia.org/resource/Kildare: [-3.243395 -1.4172429j   1.3857596+3.107509j   -4.235391 -0.24087338j
#  -4.92866  -2.9011385j  -1.8325447-0.09748289j]...
# Embedding for http://dbpedia.org/resource/Kildrum,_County_Donegal: [-4.856586  +2.3218307j -0.09242921+2.3084078j  3.2026284 -1.5886087j
#  -2.4755797 +3.2034051j -6.5585613 +4.1996837j]...
# Embedding for http://dbpedia.org/resource/Killala: [-2.6246893 +6.0431733j -0.10024437+0.141156j   0.5039811 -4.5712233j
#   0.3080941 +1.9076506j  0.45820108+3.6178966j]...
# Embedding for http://dbpedia.org/resource/Killarney: [ 5.0747924+4.0685124j  -3.2319965-2.3435385j  -5.748341 -0.62020934j
#   4.191927 +5.1198096j  -0.9597171+2.0852656j ]...
# Embedding for http://dbpedia.org/resource/Killavullen: [ 1.2294989+6.674056j  -0.6772945+2.425297j   6.0858283-3.914727j
#  -4.8432274-1.6813803j -2.855023 -1.8453106j]...
# Embedding for http://dbpedia.org/resource/Killygordon: [-1.6856583+3.2988853j -1.6372534-4.8974094j  1.041704 +2.810699j
#  -1.9421259+0.7839376j -4.639544 -4.115727j ]...
# Embedding for http://dbpedia.org/resource/Kilmacrennan: [-0.9203893 +2.4189768j  -0.16641094-2.1036994j   3.4833379 +3.0366669j
#   2.2744143 +1.2342119j  -4.644698  -0.33493155j]...
# Embedding for http://dbpedia.org/resource/Kilmovee: [ 4.076931 +7.8248j    -5.1568074+6.8007793j  2.8983564+1.6917682j
#  -1.3465527+3.2682183j -5.754718 +0.7901024j]...
# Embedding for http://dbpedia.org/resource/Kilrush: [ 1.6545707+2.476635j    2.4095974+4.5628333j   1.1793478-0.34479767j
#   2.2004647+5.1121445j  -5.4906406+0.86751896j]...
# Embedding for http://dbpedia.org/resource/Kilworth: [ 7.7721157 +2.893804j   3.2444599 -4.650917j  -4.7426662 -2.1066217j
#  -3.8555384 +4.9910803j -0.06653956-0.8861788j]...
# Embedding for http://dbpedia.org/resource/Laghy: [-0.59218436+3.212548j   -1.1432744 +1.8817246j   0.39875254+0.87362176j
#   0.39549056+0.51307416j -3.146895  +0.4968646j ]...
# Embedding for http://dbpedia.org/resource/Lahardane: [-1.8741051+3.3939202j -1.2045557+3.108394j   4.136068 -4.0879173j
#  -5.373916 +3.6138732j  5.142104 +1.2845049j]...
# Embedding for http://dbpedia.org/resource/Blasket_Islands: [ 7.0228033+0.86628896j -8.225482 +0.87044126j  2.9784324-0.7615294j
#  -0.3438337-1.0946186j  -2.8938413+8.249301j  ]...
# Embedding for http://dbpedia.org/resource/Sutton,_Dublin: [-7.812484  -1.0229883j  -2.8822246 -0.6112936j   0.85253614+0.6027151j
#  -2.5639875 +2.0701478j   3.5449617 +0.29266497j]...
# Embedding for http://dbpedia.org/resource/Dingle: [ 0.6738422 -1.1003634j -2.174694  +2.6398845j -1.4974527 -2.0356925j
#  -0.22125928+0.9897861j -1.0187485 -0.1800968j]...
# Embedding for http://dbpedia.org/resource/Dinish_Island: [-1.8294723+1.6604264j -5.592371 +6.4229984j -1.4553852-2.9363396j
#  -5.8229046+4.0855846j  3.127138 +1.9875375j]...
# Embedding for http://dbpedia.org/resource/Doorin_Peninsula: [-1.4248604 +5.688775j    0.56457585-7.350558j   -0.35464847+0.37534368j
#  -6.5193696 -1.3759289j   1.8135836 -1.1403004j ]...
# Embedding for http://dbpedia.org/resource/Dorinish: [-0.4348215 +3.1426919j  -0.8608419 +9.686927j    3.2965603 +1.9356567j
#   0.46136677+0.46748185j -1.5649323 +0.01106345j]...
# Embedding for http://dbpedia.org/resource/Manorcunningham: [-2.6227279 +8.391029j  -3.7368155 -2.306892j  -1.5462215 +1.3869541j
#  -1.2847204 -0.4906582j  0.08114248+3.8889916j]...
# Embedding for http://dbpedia.org/resource/Manorhamilton: [ 1.5299193 +6.9049788j   0.79959095+2.632561j   -2.0504346 -3.8204706j
#   2.2912621 -2.7571785j   1.4906625 -0.49501592j]...
# Embedding for http://dbpedia.org/resource/Piercetown,_County_Wexford: [-1.482617  +4.5097423j   0.3608986 -2.691117j   -4.998742  +0.50602597j
#   0.31121224+2.350111j   -0.98491216-2.0660992j ]...
# Embedding for http://dbpedia.org/resource/Porthall: [-3.543869  +5.0562725j -2.0558155 +0.760993j   0.19777887-4.8106804j
#  -0.23143701-0.9364935j -3.393736  -1.4133792j]...
# Embedding for http://dbpedia.org/resource/Mullaghlea_Glen: [ 0.28366473+2.1819508j -0.89480793+1.9948033j -2.0350199 -0.3790189j
#  -2.0333142 +0.6593209j -1.2370043 +1.0709145j]...
# Embedding for http://dbpedia.org/resource/Greater_Dublin_Area: [ 3.4525568 +4.368548j   0.16086075-6.152949j   0.29769206+4.5128393j
#  -5.1824613 +5.980512j   0.03164767+2.8214986j]...
# Embedding for http://dbpedia.org/resource/Illanmaster: [-0.87929136+1.3986032j -4.1292114 +2.6558273j  3.44553   +3.8570216j
#  -0.13081147+4.09583j   -0.41438004-0.8584675j]...
# Embedding for http://dbpedia.org/resource/Illauneeragh: [ 1.4974881 +4.901656j    0.23249392+4.774683j    0.9546681 +1.1682149j
#  -3.7915146 +0.04363751j -1.8117318 +1.878888j  ]...
# Embedding for http://dbpedia.org/resource/Illauneeragh_West: [ 1.3808223 +1.1904805j  -5.455377  +4.943737j   -0.92213917+0.77300644j
#  -4.102405  +0.7777646j  -2.1658206 -4.1084723j ]...
# Embedding for http://dbpedia.org/resource/Inchaghaun: [-0.20463213+7.3829303j -3.1164691 -4.063335j   1.7154365 +0.3874751j
#  -1.3617638 +2.7814603j  0.76332927+7.647593j ]...
# Embedding for http://dbpedia.org/resource/Inchagoill: [-0.47685143+3.6595218j  0.26949537+5.383026j   3.3145328 +2.6704698j
#  -5.34772   +3.8821898j  1.0473912 -2.41053j  ]...
# Embedding for http://dbpedia.org/resource/Inchamakinna: [-6.316826 +8.850572j   -3.4654965-1.7303599j   5.7969427-3.3332863j
#  -5.8855643+0.11491937j -5.3857427+1.4694465j ]...
# Embedding for http://dbpedia.org/resource/Inchbofin: [-1.3591183+3.2244127j -4.526932 +5.638146j  -4.8302035-1.4187702j
#   3.8531473+4.767555j  -3.239479 -0.7476872j]...
# Embedding for http://dbpedia.org/resource/Inis_Cealtra: [-0.41541365+5.658263j   0.65248996+4.546198j  -2.4485857 +1.9590588j
#   0.15666679+2.5189192j  3.9896123 -0.4395477j]...
# Embedding for http://dbpedia.org/resource/Inis_na_Bró: [ 2.5556    +2.3215966j   0.28764257+0.3235004j   0.5911661 -0.36955276j
#  -4.8681946 -2.0591087j   2.1204648 -0.6567111j ]...
# Embedding for http://dbpedia.org/resource/Inishark: [-1.8996677+6.7675624j  -5.719885 +4.8526216j   1.582191 -0.52442247j
#  -6.668133 +0.77844566j -0.667571 -2.5779989j ]...
# Embedding for http://dbpedia.org/resource/Inishbiggle: [-2.4905908 +3.4157684j -7.626153  +3.6995502j  0.40197742+2.077472j
#  -3.7465434 +2.2836087j  1.0334672 +1.4270126j]...
# Embedding for http://dbpedia.org/resource/Inishbofin,_County_Donegal: [-2.3587604 +5.1758027j -0.43659595+5.0291114j  2.6464972 -4.9683576j
#  -2.815275  -3.6263475j -5.7498407 -2.1934178j]...
# Embedding for http://dbpedia.org/resource/Inishbofin,_County_Galway: [-0.76753104+2.9003625j  -2.7624466 +1.9008776j   2.777237  +4.7664833j
#  -4.0913863 +4.424883j    3.0295753 -0.16699798j]...
# Embedding for http://dbpedia.org/resource/Inishcorker: [-3.8317902+1.4957446j  -2.6301517+3.1722288j   1.0642264+2.2872002j
#  -5.0338397+3.6495183j  -4.318513 -0.33057845j]...
# Embedding for http://dbpedia.org/resource/Inishdalla: [-2.8017228 +2.521363j  -1.1569545 +5.6092067j  0.84352183+1.5731956j
#  -2.2053325 +3.683796j  -0.80591214-0.6614742j]...
# Embedding for http://dbpedia.org/resource/Inisheer: [-3.1770813 +3.9383307j -6.3532853 +1.6344796j -2.787113  -5.2011786j
#  -1.3205726 +6.0795603j  0.17382693-1.1843191j]...
# Embedding for http://dbpedia.org/resource/Inisheltia: [ 0.95359087+5.8749504j  -1.1796304 +5.766216j    1.1130371 +0.612789j
#  -2.6432922 +5.2797365j   3.0615861 -0.62183976j]...
# Embedding for http://dbpedia.org/resource/Inishfarnard: [-2.2308805 -0.18551764j  4.0862107 +3.191488j    5.7524166 -0.05948223j
#  -5.6706367 +7.026269j    0.35901225+0.37028396j]...
# Embedding for http://dbpedia.org/resource/Inishfree: [ 1.6653928+5.509733j    1.3340788+4.3388815j   2.9824672+0.04776877j
#  -0.920327 -1.923141j   -3.2442098+5.0974317j ]...
# Embedding for http://dbpedia.org/resource/Inishkeel: [-5.427351  +4.372518j   0.46917695+5.876103j  -1.9808139 -4.2517576j
#   2.1451604 -3.5994403j  0.91989356-2.563122j ]...
# Embedding for http://dbpedia.org/resource/Inishloe: [-1.431526  +3.721244j    1.6918467 +2.9351315j   3.8138146 -0.30718273j
#  -0.14157335+1.3600742j   2.8494558 -3.6184704j ]...
# Embedding for http://dbpedia.org/resource/Inishlyre: [-1.1276706 +4.3699036j -1.9083085 +0.2132327j  3.0482264 +3.5795174j
#  -0.3250897 +3.380165j  -0.09291159-2.3026814j]...
# Embedding for http://dbpedia.org/resource/Inishmaan: [-4.0569477 +2.8236537j  -3.673202  +0.7502583j  -3.1514456 -1.836404j
#   0.3086423 +2.3086092j  -0.11330493-0.21170636j]...
# Embedding for http://dbpedia.org/resource/Inishmacowney: [-2.715855  +4.6872087j  -0.11084079-0.14065789j  1.4853648 +1.5184923j
#  -1.7176355 +3.372655j    0.03144293-3.270771j  ]...
# Embedding for http://dbpedia.org/resource/Inishmeane: [ 1.7938908+8.039369j    0.769916 +0.06468166j  3.843779 -4.3485665j
#  -4.0668454-1.7467487j  -3.1405933-1.2594963j ]...
# Embedding for http://dbpedia.org/resource/Inishmore: [-2.3125446+8.171372j  -8.017245 +5.473652j  -5.5293465-3.8474448j
#  -2.8616805+5.592867j  -1.3168807+3.0868368j]...
# Embedding for http://dbpedia.org/resource/Inishmurray: [ 0.01219119-1.299696j   -3.1091092 +0.7013541j  -1.3587883 -0.79142183j
#  -4.7622695 -2.8259432j   2.0175638 -1.1917893j ]...
# Embedding for http://dbpedia.org/resource/Inishnee: [-0.53984374+4.7795095j  -6.3236856 +3.381324j    3.6605856 +0.18420877j
#  -4.138909  +3.4599736j   0.49826464+2.0982528j ]...
# Embedding for http://dbpedia.org/resource/Inishsirrer: [ 2.2572336+5.9131985j  -1.0155077+0.35200572j  2.84223  -0.22331949j
#  -2.9582417-0.25030723j  0.1254343-0.09210305j]...
# Embedding for http://dbpedia.org/resource/Inishtooskert: [-0.99042666+0.60607934j -3.3007264 +6.594761j    3.239216  +1.2360584j
#   3.4049506 +1.3050382j  -0.14616172-2.206017j  ]...
# Embedding for http://dbpedia.org/resource/Inishtrahull: [-4.740152  +7.2261844j -0.36847392+3.2867987j  3.3165383 -4.0569997j
#  -2.822442  -1.6489031j -3.9483871 +1.0332421j]...
# Embedding for http://dbpedia.org/resource/Inishturk: [ 0.83538663+5.083011j  -2.2339382 +3.0775664j -1.7832875 +4.7524576j
#  -0.47561637+1.7157061j  2.4950755 +2.1854277j]...
# Embedding for http://dbpedia.org/resource/Inishturk_South: [-2.572029 +7.3363013j  -1.0714152+1.9936539j  -1.0577501-1.318457j
#  -2.2355886+0.05428868j -1.211649 -0.5971079j ]...
# Embedding for http://dbpedia.org/resource/Inishvickillane: [ 2.3452463+2.8842294j -2.2283118+5.0803437j  2.7897642+0.7654923j
#   1.4040614-3.6662304j -4.8176293+4.7944694j]...
# Embedding for http://dbpedia.org/resource/Innisfallen: [ 2.6296408+7.083456j  -2.1793423+4.8969693j  4.110548 +3.3043647j
#  -2.765852 +3.8672996j  4.53059  -2.0132663j]...
# Embedding for http://dbpedia.org/resource/Knocknagree: [-0.25881338+0.1691811j  -1.6331581 +2.4971035j   1.5512809 -2.3096757j
#   2.6887062 +0.35309988j -5.721086  +4.207611j  ]...
# Embedding for http://dbpedia.org/resource/Knockvicar: [-2.991723 +2.8845968j   3.1839528+1.1810797j  -1.4148815+0.33484614j
#  -3.8796854+3.3321524j  -1.0205895+6.046478j  ]...
# Embedding for http://dbpedia.org/resource/Millstreet: [ 0.58943033+4.011096j   0.25532046+3.1389132j -4.9419236 +3.3698041j
#  -6.4373136 +2.3206148j  1.8457396 +1.7448305j]...
# Embedding for http://dbpedia.org/resource/Milltown_Malbay: [-1.7875202 +3.3136659j  -0.79375106+5.137615j    5.1781445 +3.4788456j
#   3.3788936 +0.01691235j -1.1668376 +3.2707763j ]...
# Embedding for http://dbpedia.org/resource/Nenagh: [ 0.24357472+0.61049056j  1.9453077 +0.6361481j  -5.7365294 +3.8996344j
#   2.07158   -0.8223757j  -0.5120874 -3.7482748j ]...
# Embedding for http://dbpedia.org/resource/Newbliss: [-0.05889758+2.3536973j  -0.08294793+3.1260123j   0.1873536 -1.5014809j
#  -2.3832088 +0.46112034j  0.95037997+0.63958806j]...
# Embedding for http://dbpedia.org/resource/Newcastle_West: [-5.2765894 -3.1990085j  -0.79980695-1.4298447j  -2.417709  +2.818277j
#  -0.05469095-2.590212j   -4.2522383 +0.18171994j]...
# Embedding for http://dbpedia.org/resource/Newport,_County_Mayo: [-2.9556222 +3.0650585j  -0.99653345+7.046172j    3.1705093 -2.7571776j
#  -3.4765599 +3.7957644j  -1.2251236 +0.77273667j]...
# Embedding for http://dbpedia.org/resource/Newtown_Cunningham: [-4.308473  +6.6832056j -1.8286484 -3.334932j   0.24259843+1.5653299j
#  -1.9303018 -0.9850007j -4.966389  +3.7172928j]...
# Embedding for http://dbpedia.org/resource/Newtownmountkennedy: [-1.1452535+6.0279684j  -1.8939269-1.9032656j  -2.0244608+0.96019065j
#  -5.4534583-0.05482011j  1.8914896-5.13797j   ]...
# Embedding for http://dbpedia.org/resource/Oileán_Ruaidh: [-0.9959727 +3.8824265j -2.1043077 +3.380846j   0.21340926-6.1033044j
#  -4.5663533 +3.6173675j -2.5888126 +4.50733j  ]...
# Embedding for http://dbpedia.org/resource/Omey_Island: [ 1.3094084 +1.0145082j  -4.31003   +0.16058405j -1.8372452 +5.5427423j
#  -1.8715377 +3.3363729j  -0.32253495-3.202825j  ]...
# Embedding for http://dbpedia.org/resource/Raharney: [-0.7804227+2.8741665j  3.7040706+3.2686574j -1.3832515+1.1170083j
#  -2.5877607+3.0580208j  3.9928644+1.4182191j]...
# Embedding for http://dbpedia.org/resource/Rathcoole,_Dublin: [-1.8354188-1.7970599j  3.057047 -4.8725247j  2.0877817+3.8266547j
#  -1.7753395+3.598593j   0.3236333+2.7127604j]...
# Embedding for http://dbpedia.org/resource/Rathdangan: [ 1.2061324+1.2234412j  1.0983741-4.6014166j  3.4421432-3.8436267j
#  -4.820319 +3.856603j   3.8237128+4.7403455j]...
# Embedding for http://dbpedia.org/resource/Rathmore,_County_Kildare: [-0.6708397+1.9580808j  3.868829 +3.7754505j -2.1111164-1.0022317j
#   1.9117204+2.9984834j -1.1061538-1.1780763j]...
# Embedding for http://dbpedia.org/resource/Rathmullan: [ 1.0749167 +4.3726983j  -0.91500765+3.821533j    0.2114599 -3.0354643j
#  -0.82721645-0.05204843j -1.1622363 +2.0301604j ]...
# Embedding for http://dbpedia.org/resource/Redcross: [-4.7718415+5.7875547j  4.322486 +4.293122j   4.291312 +1.3152193j
#  -2.6674063-4.641318j   2.047377 +0.7321292j]...
# Embedding for http://dbpedia.org/resource/Shanbally: [ 2.5048356 +2.301636j    0.58862776-0.61422324j -0.62776846-4.5318117j
#  -1.0771134 -1.2572066j   0.2757271 +3.5026848j ]...
# Embedding for http://dbpedia.org/resource/Shannon,_County_Clare: [-2.1933587+0.15819743j  4.939278 +2.769337j    1.7926675+1.689449j
#   1.7150143+2.3559244j  -1.903622 +2.5769527j ]...
# Embedding for http://dbpedia.org/resource/Shenick_Island: [ 0.68861103+1.7636873j -5.38625   +1.8700951j -3.9264696 +4.1172833j
#  -6.4311476 +3.6651077j  0.16177604+1.3013372j]...
# Embedding for http://dbpedia.org/resource/Sherkin_Island: [ 4.0126214 +7.614816j   0.17794603+1.2125982j -2.7029834 -2.0603733j
#   2.292529  +4.9216466j  6.5976305 +1.7953491j]...
# Embedding for http://dbpedia.org/resource/Shillelagh,_County_Wicklow: [-2.8635173 +4.081371j   2.4016993 +1.6590332j -0.14323854+0.2738303j
#   0.30146822-1.0286928j  0.7264939 -1.5018766j]...
# Embedding for http://dbpedia.org/resource/Rosses_Point_Peninsula: [-4.7086368 +8.009765j  -2.9709532 -2.9124758j -0.11850929-4.866367j
#  -1.0235889 +2.362757j  -4.6652617 +1.4172457j]...

# %%
def compute_similar_places(entity_repr, top_k=10):
    entities = list(entity_repr.keys())
    all_embeddings = torch.stack([entity_repr[e] for e in entities])  # [N, D]
    sims = F.cosine_similarity(all_embeddings.unsqueeze(1), all_embeddings.unsqueeze(0), dim=-1)

    similar_places_dict = {}
    for i, e in enumerate(entities):
        sim_scores = sims[i]
        topk = torch.topk(sim_scores, k=top_k+1)  # +1 to skip itself
        indices = topk.indices.tolist()
        similar_entities = [entities[j] for j in indices if j != i][:top_k]
        similar_places_dict[e] = similar_entities
    return similar_places_dict

# %%
entity_embeddings_tensor = {
    k: torch.tensor(v, dtype=torch.float32)
    for k, v in entity_embeddings.items()
}
# Out:
# /tmp/ipython-input-2531081496.py:2: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at /pytorch/aten/src/ATen/native/Copy.cpp:309.)
#   k: torch.tensor(v, dtype=torch.float32)

# %%
entity_repr = entity_embeddings_tensor

# %%
ground_truth = pd.read_csv("./ground_truth.csv")
y_true_dict = ground_truth.groupby('geographical_entity_1')['geographical_entity_2'].apply(list).to_dict()

# %%
similar_places = compute_similar_places(entity_repr, top_k=10)

# %%
def evluation(k, y_true_dict, similar_places_dict):
  invalid_places = []
  # Compute metrics
  precisions, recalls, ndcgs, hits, map_scores,mrrs = [], [], [], [], [], []
  place_idxs = list(y_true_dict.keys())

  for pid in place_idxs:
      if pid not in similar_places_dict or len(similar_places_dict[pid]) < k:
          invalid_places.append(pid)
          continue
      pred_list, rel_set = similar_places_dict[pid][:k], y_true_dict[pid]
      pred_real = "pid:"+str(pid)+' '+"pred_list:"+str(pred_list)+' '+"rel_set:"+str(rel_set)

      if len(pred_list) == 0:
          continue


      dcg = 0.0
      hit_num = 0.0
      for i in range(len(pred_list)):
          if pred_list[i] in rel_set:
              dcg += 1. / (log(i + 2) / log(2))
              hit_num += 1
      # idcg
      idcg = 0.0
      for i in range(min(len(rel_set), len(pred_list))):
          idcg += 1. / (log(i + 2) / log(2))
      ndcg = dcg / idcg
      recall = hit_num / len(rel_set)
      precision = hit_num / len(pred_list)
      hit = 1.0 if hit_num > 0.0 else 0.0

      #map
      map_score = 0.0
      num_hits = 0.0
      score = 0.0
      for i,p in enumerate(pred_list):
          if p in rel_set and p not in pred_list[:i]:
              num_hits+=1.0
              score+=num_hits/(i+1.0)
      map_score = score/min(len(rel_set),k)
      #map_score = score / min(len(rel_set), len(pred_list)) if len(rel_set) > 0 else 0.0

      #MRR
      rr = 0.0
      for i, p in enumerate(pred_list):
          if p in rel_set:
              rr = 1.0 / (i + 1.0)
              break

      ndcgs.append(ndcg)
      recalls.append(recall)
      precisions.append(precision)
      hits.append(hit)
      map_scores.append(map_score)
      mrrs.append(rr)

  avg_precision = np.mean(precisions) * 100
  avg_recall = np.mean(recalls) * 100
  avg_ndcg = np.mean(ndcgs) * 100
  avg_hit = np.mean(hits) * 100
  avg_map = np.mean(map_scores) * 100
  avg_mrr = np.mean(mrrs) * 100

  print("invalid places:", str(len(invalid_places)))
  print('MAP={:.3f} | NDCG={:.3f} |  Recall={:.3f} | Precision={:.3f} | Hits={:.3f} | MRR={:.3f}'.format(
          avg_map, avg_ndcg, avg_recall, avg_precision, avg_hit, avg_mrr))

# %%
#kg embedding RotatE
evluation(k=10, y_true_dict=y_true_dict, similar_places_dict=similar_places)
# Out:
# invalid places: 0
# MAP=22.508 | NDCG=37.191 |  Recall=17.088 | Precision=33.345 | Hits=94.198 | MRR=66.128

# %%
#kg embedding Tucker
evluation(k=10, y_true_dict=y_true_dict, similar_places_dict=similar_places)
# Out:
# invalid places: 0
# MAP=21.487 | NDCG=34.600 |  Recall=15.855 | Precision=31.058 | Hits=93.174 | MRR=63.278
